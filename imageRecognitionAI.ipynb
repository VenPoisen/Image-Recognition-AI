# %% [markdown]
# <a href="https://colab.research.google.com/github/VenPoisen/Image-Recognition-AI/blob/main/imageRecognitionAI.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Projeto do DIO Python Day

# %%
import tensorflow as tf

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
import os 
import matplotlib.pyplot as plt
import numpy as np

# %%
import logging
logger = tf.get_logger()
logger.setLevel(logging.ERROR)

# %%
_URL = 'https://storage.googleapis.com/mledu-datasets/cats_and_dogs_filtered.zip'
zip_dir = tf.keras.utils.get_file('cats_and_dogs_filterted.zip', origin=_URL, extract=True)
# Out:
# Downloading data from https://storage.googleapis.com/mledu-datasets/cats_and_dogs_filtered.zip
# 68606236/68606236 [==============================] - 1s 0us/step

# %% [markdown]
# cats_and_dogs_filtered
# |__ train
#     |______ cats: [cat.0.jpg, cat.1.jpg, cat.2.jpg ...]
#     |______ dogs: [dog.0.jpg, dog.1.jpg, dog.2.jpg ...]
# |__ validation
#     |______ cats: [cat.2000.jpg, cat.2001.jpg, cat.2002.jpg ...]
#     |______ dogs: [dog.2000.jpg, dog.2001.jpg, dog.2002.jpg ...]

# %%
zip_dir_base = os.path.dirname(zip_dir)
# !find $zip_dir_base -type d -print
# Out:
# /root/.keras/datasets
# /root/.keras/datasets/cats_and_dogs_filtered
# /root/.keras/datasets/cats_and_dogs_filtered/train
# /root/.keras/datasets/cats_and_dogs_filtered/train/dogs
# /root/.keras/datasets/cats_and_dogs_filtered/train/cats
# /root/.keras/datasets/cats_and_dogs_filtered/validation
# /root/.keras/datasets/cats_and_dogs_filtered/validation/dogs
# /root/.keras/datasets/cats_and_dogs_filtered/validation/cats

# %%
base_dir = os.path.join(os.path.dirname(zip_dir), 'cats_and_dogs_filtered')
train_dir = os.path.join(base_dir, 'train')
validation_dir = os.path.join(base_dir, 'validation')

train_cats_dir = os.path.join(train_dir, 'cats')  # directory with our training cat pictures
train_dogs_dir = os.path.join(train_dir, 'dogs')  # directory with our training dog pictures
validation_cats_dir = os.path.join(validation_dir, 'cats')  # directory with our validation cat pictures
validation_dogs_dir = os.path.join(validation_dir, 'dogs')  # directory with our validation dog pictures

# %%
num_cats_tr = len(os.listdir(train_cats_dir))
num_dogs_tr = len(os.listdir(train_dogs_dir))

num_cats_val = len(os.listdir(validation_cats_dir))
num_dogs_val = len(os.listdir(validation_dogs_dir))

total_train = num_cats_tr + num_dogs_tr
total_val = num_cats_val + num_dogs_val

# %%
print('total training cat images:', num_cats_tr)
print('total training dog images:', num_dogs_tr)

print('total validation cat images:', num_cats_val)
print('total validation dog images:', num_dogs_val)
print("--")
print("Total training images:", total_train)
print("Total validation images:", total_val)
# Out:
# total training cat images: 1000
# total training dog images: 1000
# total validation cat images: 500
# total validation dog images: 500
# --
# Total training images: 2000
# Total validation images: 1000

# %%
BATCH_SIZE = 100  # Number of training examples to process before updating our models variables
IMG_SHAPE  = 150  # Our training data consists of images with width of 150 pixels and height of 150 pixels

# %%
train_image_generator      = ImageDataGenerator(rescale=1./255)  # Generator for our training data
validation_image_generator = ImageDataGenerator(rescale=1./255)  # Generator for our validation data

# %%
train_data_gen = train_image_generator.flow_from_directory(batch_size=BATCH_SIZE,
                                                           directory=train_dir,
                                                           shuffle=True,
                                                           target_size=(IMG_SHAPE,IMG_SHAPE), #(150,150)
                                                           class_mode='binary')
# Out:
# Found 2000 images belonging to 2 classes.

# %%
val_data_gen = validation_image_generator.flow_from_directory(batch_size=BATCH_SIZE,
                                                              directory=validation_dir,
                                                              shuffle=False,
                                                              target_size=(IMG_SHAPE,IMG_SHAPE), #(150,150)
                                                              class_mode='binary')
# Out:
# Found 1000 images belonging to 2 classes.

# %%
sample_training_images, _ = next(train_data_gen)

# %%
# This function will plot images in the form of a grid with 1 row and 5 columns where images are placed in each column.
def plotImages(images_arr):
    fig, axes = plt.subplots(1, 5, figsize=(20,20))
    axes = axes.flatten()
    for img, ax in zip(images_arr, axes):
        ax.imshow(img)
    plt.tight_layout()
    plt.show()

# %%
plotImages(sample_training_images[:5])  # Plot images 0-4

# %%
model = tf.keras.models.Sequential([
    tf.keras.layers.Conv2D(32, (3,3), activation='relu', input_shape=(150, 150, 3)),
    tf.keras.layers.MaxPooling2D(2, 2),

    tf.keras.layers.Conv2D(64, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),
    
    tf.keras.layers.Conv2D(128, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),
    
    tf.keras.layers.Conv2D(128, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),
    
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(512, activation='relu'),
    tf.keras.layers.Dense(2)
])

# %%
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 148, 148, 32)      896
#
#  max_pooling2d (MaxPooling2D  (None, 74, 74, 32)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 72, 72, 64)        18496
#
#  max_pooling2d_1 (MaxPooling  (None, 36, 36, 64)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 34, 34, 128)       73856
#
#  max_pooling2d_2 (MaxPooling  (None, 17, 17, 128)      0
#  2D)
#
#  conv2d_3 (Conv2D)           (None, 15, 15, 128)       147584
#
#  max_pooling2d_3 (MaxPooling  (None, 7, 7, 128)        0
#  2D)
#
#  flatten (Flatten)           (None, 6272)              0
#
#  dense (Dense)               (None, 512)               3211776
#
#  dense_1 (Dense)             (None, 2)                 1026
#
# =================================================================
# Total params: 3,453,634
# Trainable params: 3,453,634
# Non-trainable params: 0
# _________________________________________________________________

# %%
EPOCHS = 100
history = model.fit(
    train_data_gen,
    steps_per_epoch=int(np.ceil(total_train / float(BATCH_SIZE))),
    epochs=EPOCHS,
    validation_data=val_data_gen,
    validation_steps=int(np.ceil(total_val / float(BATCH_SIZE)))
)
# Out:
# <ipython-input-27-d70e0a339f06>:2: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   history = model.fit_generator(
# Epoch 1/100
# 20/20 [==============================] - 105s 5s/step - loss: 0.7078 - accuracy: 0.5180 - val_loss: 0.6912 - val_accuracy: 0.5000
# Epoch 2/100
# 20/20 [==============================] - 109s 5s/step - loss: 0.6921 - accuracy: 0.5090 - val_loss: 0.6922 - val_accuracy: 0.5000
# Epoch 3/100
# 20/20 [==============================] - 108s 5s/step - loss: 0.6889 - accuracy: 0.5350 - val_loss: 0.6761 - val_accuracy: 0.5750
# Epoch 4/100
# 20/20 [==============================] - 104s 5s/step - loss: 0.6861 - accuracy: 0.5660 - val_loss: 0.6888 - val_accuracy: 0.5020
# Epoch 5/100
# 20/20 [==============================] - 102s 5s/step - loss: 0.6835 - accuracy: 0.5665 - val_loss: 0.6757 - val_accuracy: 0.5480
# Epoch 6/100
# 20/20 [==============================] - 109s 6s/step - loss: 0.6773 - accuracy: 0.5740 - val_loss: 0.6704 - val_accuracy: 0.5670
# Epoch 7/100
# 20/20 [==============================] - 105s 5s/step - loss: 0.6664 - accuracy: 0.5930 - val_loss: 0.7022 - val_accuracy: 0.5270
# Epoch 8/100
# 20/20 [==============================] - 98s 5s/step - loss: 0.6573 - accuracy: 0.6035 - val_loss: 0.6372 - val_accuracy: 0.6510
# Epoch 9/100
# 20/20 [==============================] - 103s 5s/step - loss: 0.6178 - accuracy: 0.6665 - val_loss: 0.6678 - val_accuracy: 0.6060
# Epoch 10/100
# 20/20 [==============================] - 107s 5s/step - loss: 0.5953 - accuracy: 0.6840 - val_loss: 0.5758 - val_accuracy: 0.6980
# Epoch 11/100
# 20/20 [==============================] - 108s 5s/step - loss: 0.5310 - accuracy: 0.7300 - val_loss: 0.5702 - val_accuracy: 0.6940
# Epoch 12/100
# 20/20 [==============================] - 110s 6s/step - loss: 0.4815 - accuracy: 0.7845 - val_loss: 0.5412 - val_accuracy: 0.7300
# Epoch 13/100
# 20/20 [==============================] - 110s 6s/step - loss: 0.4233 - accuracy: 0.8130 - val_loss: 0.5503 - val_accuracy: 0.7130
# Epoch 14/100
# 20/20 [==============================] - 105s 5s/step - loss: 0.3972 - accuracy: 0.8195 - val_loss: 0.5570 - val_accuracy: 0.7270
# Epoch 15/100
# 20/20 [==============================] - 111s 6s/step - loss: 0.3263 - accuracy: 0.8600 - val_loss: 0.6283 - val_accuracy: 0.7130
# Epoch 16/100
# 20/20 [==============================] - 103s 5s/step - loss: 0.3026 - accuracy: 0.8690 - val_loss: 0.5895 - val_accuracy: 0.7300
# Epoch 17/100
# 20/20 [==============================] - 110s 6s/step - loss: 0.2488 - accuracy: 0.9000 - val_loss: 0.6396 - val_accuracy: 0.7340
# Epoch 18/100
# 20/20 [==============================] - 104s 5s/step - loss: 0.2395 - accuracy: 0.8960 - val_loss: 0.6733 - val_accuracy: 0.7260
# Epoch 19/100
# 20/20 [==============================] - 103s 5s/step - loss: 0.1493 - accuracy: 0.9435 - val_loss: 0.8116 - val_accuracy: 0.7090
# Epoch 20/100
# 20/20 [==============================] - 104s 5s/step - loss: 0.1177 - accuracy: 0.9540 - val_loss: 0.8363 - val_accuracy: 0.7240
# Epoch 21/100
# 20/20 [==============================] - 109s 5s/step - loss: 0.1191 - accuracy: 0.9510 - val_loss: 0.8901 - val_accuracy: 0.7350
# Epoch 22/100
# 20/20 [==============================] - 101s 5s/step - loss: 0.0727 - accuracy: 0.9740 - val_loss: 1.0573 - val_accuracy: 0.7310
# Epoch 23/100
# 20/20 [==============================] - 102s 5s/step - loss: 0.0599 - accuracy: 0.9800 - val_loss: 1.1443 - val_accuracy: 0.7220
# Epoch 24/100
# 20/20 [==============================] - 103s 5s/step - loss: 0.0419 - accuracy: 0.9875 - val_loss: 1.1580 - val_accuracy: 0.7340
# Epoch 25/100
# 20/20 [==============================] - 104s 5s/step - loss: 0.0489 - accuracy: 0.9820 - val_loss: 1.1251 - val_accuracy: 0.7370
# Epoch 26/100
# 20/20 [==============================] - 103s 5s/step - loss: 0.0443 - accuracy: 0.9830 - val_loss: 1.1696 - val_accuracy: 0.7190
# Epoch 27/100
# 20/20 [==============================] - 102s 5s/step - loss: 0.0283 - accuracy: 0.9915 - val_loss: 1.3267 - val_accuracy: 0.7460
# Epoch 28/100
# 20/20 [==============================] - 102s 5s/step - loss: 0.0143 - accuracy: 0.9965 - val_loss: 1.4642 - val_accuracy: 0.7410
# Epoch 29/100
# 20/20 [==============================] - 103s 5s/step - loss: 0.0097 - accuracy: 0.9990 - val_loss: 1.4354 - val_accuracy: 0.7440
# Epoch 30/100
# 20/20 [==============================] - 109s 5s/step - loss: 0.0067 - accuracy: 0.9995 - val_loss: 1.5646 - val_accuracy: 0.7410
# Epoch 31/100
# 20/20 [==============================] - 107s 5s/step - loss: 0.0049 - accuracy: 0.9995 - val_loss: 1.4804 - val_accuracy: 0.7460
# Epoch 32/100
# 20/20 [==============================] - 101s 5s/step - loss: 0.0026 - accuracy: 0.9995 - val_loss: 1.5676 - val_accuracy: 0.7600
# Epoch 33/100
# 20/20 [==============================] - 101s 5s/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 1.6517 - val_accuracy: 0.7490
# Epoch 34/100
# 20/20 [==============================] - 106s 5s/step - loss: 5.7614e-04 - accuracy: 1.0000 - val_loss: 1.6983 - val_accuracy: 0.7590
# Epoch 35/100
# 20/20 [==============================] - 107s 5s/step - loss: 4.0174e-04 - accuracy: 1.0000 - val_loss: 1.7261 - val_accuracy: 0.7490
# Epoch 36/100
# 20/20 [==============================] - 110s 6s/step - loss: 3.2565e-04 - accuracy: 1.0000 - val_loss: 1.7516 - val_accuracy: 0.7550
# Epoch 37/100
# 20/20 [==============================] - 101s 5s/step - loss: 2.8521e-04 - accuracy: 1.0000 - val_loss: 1.7718 - val_accuracy: 0.7530
# Epoch 38/100
# 20/20 [==============================] - 101s 5s/step - loss: 2.4608e-04 - accuracy: 1.0000 - val_loss: 1.7940 - val_accuracy: 0.7560
# Epoch 39/100
# 20/20 [==============================] - 110s 6s/step - loss: 2.1755e-04 - accuracy: 1.0000 - val_loss: 1.8143 - val_accuracy: 0.7520
# Epoch 40/100
# 20/20 [==============================] - 103s 5s/step - loss: 1.9241e-04 - accuracy: 1.0000 - val_loss: 1.8349 - val_accuracy: 0.7540
# Epoch 41/100
#  1/20 [>.............................] - ETA: 1:32 - loss: 1.2992e-04 - accuracy: 1.0000

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(EPOCHS)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.savefig('./foo.png')
plt.show()
